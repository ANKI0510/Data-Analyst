# %%
#1> Calculate avg. of score provided that only positive scores are valid
 scores = (20,30,-5,10,-10,30,-18)

#2> If a number is amicable or not
#3> Check number is prime or not
#4> factorial of user defined number
#5> Nummber is armstrong no. or not

# %%
# 1> Calculate avg. of score provided that only positive scores are valid
scores = (20,30,-5,10,-10,30,-1)
sum1 = 0
for i in scores:
  if i>=0:
    sum1+= i
  else:
    continue
  print(i)
average = sum1/len(scores)
print('Average',average)
# Out:
# 20
# 30
# 10
# 30
# Average 12.857142857142858

# %%
##2> If a number is amicable or not
x=int(input('Enter first number : '))
y=int(input('Enter second number : '))
sum1=0
sum2=0
for i in range(1,x):
    if x%i==0:
        sum1+=i
for j in range(1,y):
    if y%j==0:
        sum2+=j
if(sum1==y and sum2==x):
    print('Given numbers are Amicable!')
else:
    print('Given numbers are not Amicable!')
# Out:
# Enter first number : 27
# Enter second number : 54
# Given numbers are not Amicable!

# %%
##2> If a number is amicable or not
x=int(input('Enter first number : '))
y=int(input('Enter second number : '))
fact1= []
fact2= []
for i in range(1,x):
  if x%i==0:
    fact1.append(i)
  for j in range(1,y):
    fact2.append(j)
if(y==sum(fact2) and x==sum(fact1)):
  print('Given numbers are Amicable!')
else:
  print('Given numbers are not Amicable!')

# %%
# 3> Check number is prime or not
num = 11
if num > 1:

    for i in range(2, int(num/2)+1):
        # If num is divisible by any number between
        # 2 and n / 2, it is not prime
        if (num % i) == 0:
            print(num, "is not a prime number")
            break
    else:
        print(num, "is a prime number")
else:
    print(num, "is not a prime number")
# Out:
# Enter first number : 7

# %%
x=int(input('Enter first number : '))
prime = True
for i in range(2, n):
  if x % i == 0:
    prime = False
    break
  if prime == True:
    print('The given number is prime')
  else:
    print('The given number is not prime')

# %%
#4> factorial of user defined number
x=int(input('Enter first number : '))
fact1 = 1
if n>=0
for i in range(1,x+1):
  fact1 = i* fact1
print('Factorial of ',fact1)
