# %% [markdown]
# # Name :- Ankita

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/DATASET.csv',encoding='latin1')
df
# Out:
#                Employee Name Employee Status  Salary  Pay Basis  \
# 0            Abrams, Adam W.        Employee   66300  Per Annum
# 1              Adams, Ian H.        Employee   45000  Per Annum
# 2            Agnew, David P.        Employee   93840  Per Annum
# 3             Albino, James         Employee   91800  Per Annum
# 4       Aldy, Jr., Joseph E.        Employee  130500  Per Annum
# ..                       ...             ...     ...        ...
# 464  Young, Jr., Reginald D.        Employee   60232  Per Annum
# 465      Young, Katherine H.        Employee   42000  Per Annum
# 466         Young, Latoya A.        Employee   58511  Per Annum
# 467       Zelman, Allison L.        Employee   50000  Per Annum
# 468       Zichal, Heather R.        Employee  100000  Per Annum
#
#                                         Position Title  order_id  quantity  \
# 0             WESTERN REGIONAL COMMUNICATIONS DIRECTOR         1         1
# ...

# %%
df.head(10)
# Out:
#           Employee Name Employee Status  Salary  Pay Basis  \
# 0       Abrams, Adam W.        Employee   66300  Per Annum
# 1         Adams, Ian H.        Employee   45000  Per Annum
# 2       Agnew, David P.        Employee   93840  Per Annum
# 3        Albino, James         Employee   91800  Per Annum
# 4  Aldy, Jr., Joseph E.        Employee  130500  Per Annum
# 5      Alley, Hilary J.        Employee   42000  Per Annum
# 6  Amorsingh, Lucius L.        Employee   56092  Per Annum
# 7   Anderson, Amanda D.        Employee   60000  Per Annum
# 8  Anderson, Charles D.        Employee   51000  Per Annum
# 9      Andrias, Kate E.        Employee  130500  Per Annum
#
#                                       Position Title  order_id  quantity  \
# 0           WESTERN REGIONAL COMMUNICATIONS DIRECTOR         1         1
# 1  EXECUTIVE ASSISTANT TO THE DIRECTOR OF SCHEDUL...         1         1
# 2       DEPUTY DIRECTOR OF INTERGOVERNMENTAL AFFAIRS         1         1
# ...

# %%
#1. Find the salary of an employee in a (1st-row 2nd-column) using a position based indexing function?

df.iloc[[1],[2]]
# Out:
#    Salary
# 1   45000

# %%
#2. Display all the employees whose salary is greater than 50000?
df[df.Salary>50000]
# Out:
#                   Employee Name Employee Status  Salary  Pay Basis  \
# 0               Abrams, Adam W.        Employee   66300  Per Annum
# 2               Agnew, David P.        Employee   93840  Per Annum
# 3                Albino, James         Employee   91800  Per Annum
# 4          Aldy, Jr., Joseph E.        Employee  130500  Per Annum
# 6          Amorsingh, Lucius L.        Employee   56092  Per Annum
# ..                          ...             ...     ...        ...
# 462          Wright, Jessica N.        Employee   96900  Per Annum
# 463  Yeager Kaplan, Jennifer F.        Employee   66300  Per Annum
# 464     Young, Jr., Reginald D.        Employee   60232  Per Annum
# 466            Young, Latoya A.        Employee   58511  Per Annum
# 468          Zichal, Heather R.        Employee  100000  Per Annum
#
#                                         Position Title  order_id  quantity  \
# 0             WESTERN REGIONAL COMMUNICATIONS DIRECTOR         1         1
# ...

# %%
#3. Find the list of Employee details belonging to a position ('ANALYST','ADVISOR')?
df[(df.Position Title='ANALYST')|(df.Position Title='ADVISOR')]

# %%
#4. Find the top 10 highest-paid employees in each position?
df.groupby('Position Title')['Salary'].max().head(10)

# %%
#5. Select only the products with quantity equals to 1
df[df.quantity==1]['item_name']

# %%
#6. Count the item_price is greater than 1.

df.sort_values()

# %%
#7. Create a data frame with a name "discipline" consisting of (Team, Yellow Cards and Red Cards)
team ={'Team':['yellow_cards','Red_cards']}
discipline = pd.DataFrame(team)
discipline
# Out:
#            Team
# 0  yellow_cards
# 1     Red_cards
