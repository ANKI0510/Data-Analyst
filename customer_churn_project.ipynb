# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/customer_churn_dataset.csv")
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
# Checkinng duplicate values
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#checking churn values
df['Churn'].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
# creating visualization
# Create churn count chart
# adding title
# display plot

plt.figure(figsize=(6,4))


sns.countplot(
x='Churn',
data=df
)

plt.title('TelecomX Customer Churn Distribution')

plt.show()

# %%
# Gender Churn Chart

plt.figure(figsize=(8,5))

sns.countplot(
x = 'gender',
hue ='Churn',
data = df
)

plt.title('Customer Churn by Gender')
plt.show()

# %%
# Tenure Boxplot

plt.figure(figsize=(8,5))

sns.boxplot(
    y = 'Churn',
    x = 'tenure',
    data = df
)
plt.title("Tenure Analysis")
plt.show()

# %%
# Select numerical columns

numeric_df = df.select_dtypes(
include=np.number
)

# Create correlation matrix

correlation = numeric_df.corr()

# Plot heatmap

plt.figure(
figsize=(10,6)
)

sns.heatmap(
correlation,
annot=True,
cmap='coolwarm'
)

plt.title(
'Correlation Heatmap'
)

plt.show()

# %%
# Data Inspection
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
# Check Gender Values
df['gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
# Check Churn Values.
df['Churn'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
# Find Object Columns
categorical_columns = df.select_dtypes(include=object)
categorical_columns.columns
# Out:
# Index(['customerID', 'gender', 'Partner', 'Dependents', 'PhoneService',
#        'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup',
#        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
#        'Contract', 'PaperlessBilling', 'PaymentMethod', 'TotalCharges',
#        'Churn'],
#       dtype='object')

# %%
# Check Total Charges Issues.
df['TotalCharges']
# Out:
# 0         29.85
# 1        1889.5
# 2        108.15
# 3       1840.75
# 4        151.65
#          ...
# 7038     1990.5
# 7039     7362.9
# 7040     346.45
# 7041      306.6
# 7042     6844.5
# Name: TotalCharges, Length: 7043, dtype: object

# %%
from IPython.core import error
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'],
                                   errors='coerce')

# %%
df['TotalCharges']
# Out:
# 0         29.85
# 1       1889.50
# 2        108.15
# 3       1840.75
# 4        151.65
#          ...
# 7038    1990.50
# 7039    7362.90
# 7040     346.45
# 7041     306.60
# 7042    6844.50
# Name: TotalCharges, Length: 7043, dtype: float64

# %%
# Checking Null Values

df.isnull().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
# Filling Missing Values
df['TotalCharges'] = df['TotalCharges'].fillna(df['TotalCharges'].median())

# %%
df['TotalCharges']
# Out:
# 0         29.85
# 1       1889.50
# 2        108.15
# 3       1840.75
# 4        151.65
#          ...
# 7038    1990.50
# 7039    7362.90
# 7040     346.45
# 7041     306.60
# 7042    6844.50
# Name: TotalCharges, Length: 7043, dtype: float64

# %%
df['TotalCharges'].isnull().sum()
# Out:
# np.int64(0)

# %%
# Label Encoding

df['Churn'] = df['Churn'].map({'yes':1,'No':0})

# %%
df['Churn']
# Out:
# 0       0.0
# 1       0.0
# 2       NaN
# 3       0.0
# 4       NaN
#        ...
# 7038    0.0
# 7039    0.0
# 7040    0.0
# 7041    NaN
# 7042    0.0
# Name: Churn, Length: 7043, dtype: float64

# %%
df = df.drop(
'customerID',
axis=1
)

# %%
df.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
df.shape
# Out:
# (7043, 20)

# %%
df = pd.get_dummies(
df,
drop_first=True
)

# %%
df.head()
# Out:
#    SeniorCitizen  tenure  MonthlyCharges  TotalCharges  Churn  gender_Male  \
# 0              0       1           29.85         29.85    0.0        False
# 1              0      34           56.95       1889.50    0.0         True
# 2              0       2           53.85        108.15    NaN         True
# 3              0      45           42.30       1840.75    0.0         True
# 4              0       2           70.70        151.65    NaN        False
#
#    Partner_Yes  Dependents_Yes  PhoneService_Yes  \
# 0         True           False             False
# 1        False           False              True
# 2        False           False              True
# 3        False           False             False
# 4        False           False              True
#
#    MultipleLines_No phone service  ...  StreamingTV_No internet service  \
# 0                            True  ...                            False
# ...

# %%
df.shape
# Out:
# (7043, 31)

# %% [markdown]
# Feature Selection X and Y.

# %%
# Target Variable

y = df['Churn']

# %%
# Feature Columns

x = df.drop('Churn',axis=1)

# %%
# Check Feature Size
x.shape
# Out:
# (7043, 30)

# %%
# Check Target Size
y.shape
# Out:
# (7043,)

# %% [markdown]
# # ======================================
# # TRAIN TEST SPLIT
# # Concept Learning:
# # 1. Training Dataset
# # 2. Testing Dataset
# # 3. Model Validation
# # 4. Overfitting Prevention
# #
# # Purpose:
# # Split customer data into training and
# # testing sets so machine learning learns
# # patterns and is evaluated on unseen data.
# # ======================================

# %%
# Import Split Tool

from sklearn.model_selection import train_test_split

# %%
# Split Dataset

x_train,x_test,y_train,y_test = train_test_split(
   x,y,
    test_size = 0.2,
    random_state= 42

)

# %%
# Varify Shape
x_train.shape
# Out:
# (5634, 30)

# %%
x_test.shape
# Out:
# (1409, 30)

# %%
y_train.shape
# Out:
# (5634,)

# %%
y_test.shape
# Out:
# (1409,)

# %% [markdown]
# # ======================================
# #LOGISTIC REGRESSION MODEL
# #
# # Concept Learning:
# # 1. Logistic Regression
# # 2. Classification Model
# # 3. Model Training
# #
# # Purpose:
# # Train machine learning model to predict
# # customer churn using historical customer
# # information.
# # ======================================

# %%
# Import Logistic Regression

from sklearn.linear_model import LogisticRegression

# %%
# Create Machine Learning Model

model = LogisticRegression(
    max_iter = 3000
)

# %%
# Train Model Using Traing Data.

model.fit(

          x_train,
          y_train
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_2405/1505624625.py in <cell line: 0>()
#       1 # Train Model Using Traing Data.
#       2
# ----> 3 model.fit(
#       4
#       5           x_train,
#
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1220             _dtype = [np.float64, np.float32]
#    1221
# -> 1222         X, y = validate_data(
#    1223             self,
#    1224             X,
#
# ...

# %% [markdown]
# # ======================================
# # CORRECTION AFTER DEBUGGING
# #
# # Earlier target column had NaN values.
# # Recreated feature and target variables.
# # Re-trained machine learning pipeline.
# # ======================================

# %%
df['Churn'].isnull().sum()

# %%
df['Churn'].unique()

# %%
# Checking original churn values before fixing.

df['Churn'].value_counts(
    dropna=False
)

# %%
df['Churn'] = df['Churn'].fillna(1)

# %%
df['Churn'].unique()

# %%
df['Churn'].value_counts()

# %%
# Recreating Target Value
y = df['Churn']

# %%
# Creating Features
X = df.drop('Churn',axis=1)

# %%
# Again Checking y is having nan values

y.isnull().sum()

# %%
X.isnull().sum().sum()

# %%
y.shape

# %%
y_train.isnull().sum()

# %% [markdown]
# # ======================================
# # REBUILD TRAIN TEST SPLIT
# #
# # Reason:
# # Target variable corrected.
# # Old train-test split contained NaN.
# # Recreating split using corrected data.
# # ======================================

# %%
# Create target variable again

y = df['Churn']

# %%
# Create features again

X = df.drop(

'Churn',

axis=1

)

# %% [markdown]
# # Rerun from training and testion..

# %% [markdown]
# # ======================================
# # STEP 13 : MODEL EVALUATION
# #
# # Concept Learning:
# # 1. Prediction
# # 2. Accuracy Score
# # 3. Confusion Matrix
# # 4. Classification Report
# #
# # Purpose:
# # Evaluate machine learning performance
# # and measure churn prediction quality.
# # ======================================

# %%
model

# %%
y_predict = model.predict(x_test)

# %%
y_predict

# %% [markdown]
# # ======================================
# # ACCURACY SCORE
# #
# # Purpose:
# # Measure overall prediction accuracy.
# # ======================================

# %%
# Import Accuracy metric
from sklearn.metrics import accuracy_score

# %%
accuracy = accuracy_score(
    y_test,
    y_predict
)

# %%
accuracy

# %%
y_predict[:10]

# %%
accuracy_score(
    y_test,
    y_predict
)

# %% [markdown]
# # ======================================
# #  CONFUSION MATRIX
# #
# # Concept Learning:
# # 1. True Positive
# # 2. True Negative
# # 3. False Positive
# # 4. False Negative
# #
# # Purpose:
# # Analyze model prediction errors
# # and understand churn prediction
# # performance.
# # ======================================

# %%
# Import Confusion Metrix
from sklearn.metrics import confusion_matrix

# %%
conf_metrix = confusion_matrix(
    y_test,
    y_predict
)

# %%
print(conf_metrix)

# %%
# plot confusion matrix

plt.figure(figsize=(5,4))

sns.heatmap(
    conf_metrix,
    annot = True,
    fmt ='d',
    cmap = 'Blues'
)

plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Telecom Confusion Matrix')

plt.show()

# %% [markdown]
# # ======================================
# # STEP 16 : CLASSIFICATION REPORT
# #
# # Concept Learning:
# # 1. Precision
# # 2. Recall
# # 3. F1 Score
# # 4. Support
# #
# # Purpose:
# # Measure detailed model performance
# # for churn prediction.
# # ======================================

# %%
# Import Classification Report

from sklearn.metrics import classification_report

# %%
report = classification_report(
    y_test,
    y_predict
)

# %%
print(report)

# %%
# ======================================
#  BUSINESS INSIGHTS
#
# Concept Learning:
# 1. Business Insights
# 2. Data Storytelling
# 3. Recommendations
#
# Purpose:
# Convert churn analysis into
# business actions.
# ======================================

# %% [markdown]
# Business Insights:
#
# 1. Customer retention customers are predicted very well.
#
# Model Recall for Stay Customers = 90%.
#
# 2. Churn customer prediction Recall = 60%.
#
# Model still misses some churn customers.
#
# 3. Month-to-month customers show higher churn tendency.
#
# 4. Lower tenure customers are more likely to churn.
#
# 5. Long-term customers show stronger retention.
#
# Recommendations:
#
# 1. TelecomX should target low tenure customers.
#
# 2. Offer retention discounts to month-to-month customers.
#
# 3. Improve churn detection strategies.
#
# 4. Create loyalty programs for early-stage customers.
